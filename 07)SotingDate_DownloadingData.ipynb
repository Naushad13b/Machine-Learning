# %% [markdown]
# <a href="https://colab.research.google.com/github/Naushad13b/Machine-Learning/blob/main/07)SotingDate_DownloadingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10,6

# %%
df = pd.read_csv(r"/content/Data.csv")

# %%
df.head(40)
# Out:
#    Station              Date   PM2.5    PM10      NO     NO2    SO2    CO  \
# 0       1A  01-01-2021 00:00  228.53  349.22   19.35   43.16  26.73  1.53
# 1       1A  02-01-2021 00:00  222.37  313.72    13.3   36.83   31.7  1.73
# 2       1A  03-01-2021 00:00  128.14   177.7   15.94   29.33  24.19  1.29
# 3       1A  04-01-2021 00:00   68.44  104.81   26.27   40.26   21.8  1.13
# 4       1A  05-01-2021 00:00   62.51   104.2   22.32   40.63  20.09  0.98
# 5       1A  06-01-2021 00:00  122.99  185.76   56.59   68.72   21.6  1.25
# 6       1A  07-01-2021 00:00  119.15  214.43   38.48   57.54  37.88  1.03
# 7       1A  08-01-2021 00:00  121.51  224.98   33.89   41.65  55.02  1.12
# 8       1A  09-01-2021 00:00  156.75  273.34   40.73   55.38  56.47  1.18
# 9       1A  10-01-2021 00:00  119.35   227.9   37.11   52.61   59.9  0.79
# 10      1A  11-01-2021 00:00   90.12  218.45   54.14   78.02  39.01  0.97
# 11      1A  12-01-2021 00:00  127.45  255.37   37.38   56.37  46.13  1.06
# ...

# %%
 df["Date"] = pd.to_datetime(df["Date"])
print(df.dtypes)
# Out:
# Station            object
# Date       datetime64[ns]
# PM2.5              object
# PM10               object
# NO                 object
# NO2                object
# SO2                object
# CO                 object
# Ozone              object
# Temp               object
# RH                 object
# WS                 object
# WD                 object
# SR                 object
# dtype: object

# %%
df.head(40)
# Out:
#    Station       Date   PM2.5    PM10      NO     NO2    SO2    CO  Ozone  \
# 0       1A 2021-01-01  228.53  349.22   19.35   43.16  26.73  1.53   33.3
# 1       1A 2021-02-01  222.37  313.72    13.3   36.83   31.7  1.73   28.9
# 2       1A 2021-03-01  128.14   177.7   15.94   29.33  24.19  1.29  17.46
# 3       1A 2021-04-01   68.44  104.81   26.27   40.26   21.8  1.13  14.43
# 4       1A 2021-05-01   62.51   104.2   22.32   40.63  20.09  0.98   16.6
# 5       1A 2021-06-01  122.99  185.76   56.59   68.72   21.6  1.25   8.85
# 6       1A 2021-07-01  119.15  214.43   38.48   57.54  37.88  1.03  14.09
# 7       1A 2021-08-01  121.51  224.98   33.89   41.65  55.02  1.12    9.3
# 8       1A 2021-09-01  156.75  273.34   40.73   55.38  56.47  1.18   8.75
# 9       1A 2021-10-01  119.35   227.9   37.11   52.61   59.9  0.79   8.27
# 10      1A 2021-11-01   90.12  218.45   54.14   78.02  39.01  0.97   15.7
# 11      1A 2021-12-01  127.45  255.37   37.38   56.37  46.13  1.06  23.67
# ...

# %%
df.sort_values(by='Date', inplace=True)
print(df)
# Out:
#       Station       Date   PM2.5    PM10      NO     NO2    SO2    CO  Ozone  \
# 0          1A 2021-01-01  228.53  349.22   19.35   43.16  26.73  1.53   33.3
# 2190       3B 2021-01-01  469.98  515.97  207.95    97.6  24.93  4.58  40.18
# 30660     26A 2021-01-01  239.94  346.52   38.34   49.52   6.73  3.28  24.38
# 15330      9B 2021-01-01  330.78  518.81   76.66  133.43    2.5  None   0.85
# 33215     34A 2021-01-01   118.9  210.59   19.79    7.53  43.47  1.69  32.39
# ...       ...        ...     ...     ...     ...     ...    ...   ...    ...
# 9124       3T 2021-12-31  102.75  135.08   48.76   31.04   None  0.31   6.02
# 30659     25E 2021-12-31  142.83  185.53    78.2   45.85   9.31  2.17  26.74
# 8759       3S 2021-12-31  239.81  340.31   98.97   56.19   13.3  1.81  11.68
# 2919       3C 2021-12-31  258.64  362.26   85.15   51.77  10.34   NaN   4.31
# 33944     35A 2021-12-31  142.18  219.21    9.61   71.85   11.3  0.99  40.94
#
#         Temp     RH    WS      WD      SR
# ...

# %%
df.head(99)
# Out:
#       Station       Date   PM2.5    PM10      NO     NO2    SO2    CO  Ozone  \
# 0          1A 2021-01-01  228.53  349.22   19.35   43.16  26.73  1.53   33.3
# 2190       3B 2021-01-01  469.98  515.97  207.95    97.6  24.93  4.58  40.18
# 30660     26A 2021-01-01  239.94  346.52   38.34   49.52   6.73  3.28  24.38
# 15330      9B 2021-01-01  330.78  518.81   76.66  133.43    2.5  None   0.85
# 33215     34A 2021-01-01   118.9  210.59   19.79    7.53  43.47  1.69  32.39
# ...       ...        ...     ...     ...     ...     ...    ...   ...    ...
# 12441      5D 2021-01-02  375.48  501.09   11.26    59.8    5.4  2.34   1.11
# 2951       3D 2021-01-02  133.15  239.26   17.33   22.05    NaN  1.45  15.91
# 12806      6A 2021-01-02  197.72  367.34    1.54   19.08  10.55  None  33.23
# 26676     20D 2021-01-02    99.4  209.08    2.18    1.02   4.12  1.72   5.53
# 1126       2C 2021-01-02  252.53  436.28   33.36  109.34  14.57   2.5  34.25
#
#         Temp     RH    WS      WD      SR
# ...

# %%
# downloading csv file
cities = pd.DataFrame(df)
cities.to_csv('new222.csv')
