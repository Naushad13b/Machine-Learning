# %% [markdown]
# <a href="https://colab.research.google.com/github/Naushad13b/Machine-Learning/blob/main/All_mean_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv(r'/content/Book_3.csv')

# %%
data.tail(300)
# Out:
#       Unnamed: 0 Station              Date   PM2.5    PM10     NO    NO2  \
# 9190        9190      3Z  07-03-2021 00:00  145.75  319.88  37.37  60.10
# 9191        9191      3Z  08-03-2021 00:00  111.90  246.61   3.40  49.03
# 9192        9192      3Z  09-03-2021 00:00  167.93  341.86   6.93  56.16
# 9193        9193      3Z  10-03-2021 00:00   90.90  217.02  17.88  57.27
# 9194        9194      3Z  11-03-2021 00:00  156.12  291.36  41.20  63.48
# ...          ...     ...               ...     ...     ...    ...    ...
# 9485        9485      3Z  27-12-2021 00:00  121.87  211.39  33.50  25.13
# 9486        9486      3Z  28-12-2021 00:00  194.25  306.67  39.60  31.52
# 9487        9487      3Z  29-12-2021 00:00  155.07  271.92  71.41  29.03
# 9488        9488      3Z  30-12-2021 00:00  156.70  282.88  41.40  31.51
# 9489        9489      3Z  31-12-2021 00:00  170.31  291.57  20.63  28.91
#
#         SO2    CO  Ozone       Temp     RH    WS      WD      SR
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Station', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'SO2',
#        'CO', 'Ozone', 'Temp', 'RH', 'WS', 'WD', 'SR'],
#       dtype='object')

# %%
pmdata=data["PM2.5"]
pmdata1=data["PM10"]
pmdata2=data["NO"]
pmdata3=data["NO2"]
pmdata4=data["SO2"]
pmdata5=data["CO"]
pmdata6=data["Ozone"]
pmdata7=data["Temp"]
pmdata8=data["RH"]
pmdata9=data["WS"]
pmdata10=data["WD"]
pmdata11=data["SR"]

# %%
meandata=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata[s:l]
  meandata.append(x.mean())
  s=l
  l=l+26

# %%
meandata1=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata1[s:l]
  meandata1.append(x.mean())
  s=l
  l=l+26

# %%
meandata2=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata2[s:l]
  meandata2.append(x.mean())
  s=l
  l=l+26

# %%
meandata3=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata3[s:l]
  meandata3.append(x.mean())
  s=l
  l=l+26

# %%
meandata4=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata4[s:l]
  meandata4.append(x.mean())
  s=l
  l=l+26

# %%
meandata5=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata5[s:l]
  meandata5.append(x.mean())
  s=l
  l=l+26

# %%
meandata6=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata6[s:l]
  meandata6.append(x.mean())
  s=l
  l=l+26

# %%
meandata7=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata7[s:l]
  meandata7.append(x.mean())
  s=l
  l=l+26

# %%
meandata8=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata8[s:l]
  meandata8.append(x.mean())
  s=l
  l=l+26

# %%
meandata9=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata9[s:l]
  meandata9.append(x.mean())
  s=l
  l=l+26

# %%
meandata10=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata10[s:l]
  meandata10.append(x.mean())
  s=l
  l=l+26

# %%
meandata11=[]
s=0 #for strat index
l=26 #end index
for i in range(365):
  x=pmdata11[s:l]
  meandata11.append(x.mean())
  s=l
  l=l+26

# %%
d=pd.DataFrame([meandata,meandata1,meandata2,meandata3,meandata4,meandata5,meandata6,meandata7,meandata8,meandata9,meandata10,meandata11])

# %%
d
# Out:
#            0           1           2           3           4           5    \
# 0   177.457692  177.041923  114.797934   85.525385   94.883462   53.988077
# 1   242.076154  293.994231  285.880113  242.038846  249.743462  136.858462
# 2    12.648846   23.845769   15.833200    8.971923    4.553077    2.409231
# 3    21.981538   37.445385   30.457005   33.516154   27.274231   20.265385
# 4    10.996312   13.875769   22.661312   27.063077   25.679615   12.254231
# 5     0.934615    1.062308    0.899938    1.534615    1.462308    1.351476
# 6    22.750769   29.946154   49.829579   66.842656   58.697748   33.872308
# 7    25.249537   25.249537   25.249537   25.249537   25.249537   25.249537
# 8    73.310769   66.552308   53.802608   39.558846   32.330385   28.734231
# 9     1.217308    1.283077    1.282424    0.959615    0.286538    0.232308
# 10  189.037692  189.299231  202.165880  221.427308  168.367308  144.598462
# ...

# %%
# downloading csv file
SO2 = pd.DataFrame(d)
SO2.to_csv('booK3_1.csv')
